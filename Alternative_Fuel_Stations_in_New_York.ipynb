# %% [markdown]
# ## Prerequisites

# %%
import pandas as pd
import re
import plotly.express as px

# %%
# !gdown https://drive.google.com/uc?id=1jbHGsrSJt1FfDbD67H7fJAtH5e8Zxrkc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jbHGsrSJt1FfDbD67H7fJAtH5e8Zxrkc
# To: /content/Alternative_Fuel_Stations_in_New_York.xlsx
# 100% 639k/639k [00:00<00:00, 84.2MB/s]

# %%
filename = 'Alternative_Fuel_Stations_in_New_York.xlsx'
ny_stations = pd.read_excel(filename)

# %% [markdown]
# ## Exploratoring the dataframe

# %%
pd.set_option('display.max_rows', None)

# %%
ny_stations.sample(2)
# Out:
#      Fuel Type Code           Station Name   Street Address  \
# 22             ELEC        32 Burling Lane  32 Burling Lane
# 2242           ELEC  SUNY BUFFALO PARKER 6     185 Hayes Rd
#
#      Intersection Directions          City State      ZIP  Plus4  \
# 22                       NaN  New Rochelle    NY  10801.0    NaN
# 2242                     NaN       Buffalo    NY  14214.0    NaN
#
#      Station Phone Status Code  ...  EV Pricing (French) LPG Nozzle Types  \
# 22    844-623-1001           E  ...                  NaN              NaN
# 2242  888-758-4389           E  ...                  NaN              NaN
#
#      Hydrogen Pressures Hydrogen Standards CNG Fill Type Code CNG PSI  \
# 22                  NaN                NaN                NaN     NaN
# 2242                NaN                NaN                NaN     NaN
#
#       CNG Vehicle Class  LNG Vehicle Class  EV On-Site Renewable Source  \
# 22                  NaN                NaN                          NaN
# 2242                NaN                NaN                          NaN
#
#                       Georeference
# 22       POINT (-73.78588 40.9129)
# 2242  POINT (-78.822603 42.951019)
#
# [2 rows x 65 columns]

# %%
ny_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3405 entries, 0 to 3404
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    3405 non-null   object
#  1   Station Name                      3405 non-null   object
#  2   Street Address                    3405 non-null   object
#  3   Intersection Directions           117 non-null    object
#  4   City                              3401 non-null   object
#  5   State                             3401 non-null   object
#  6   ZIP                               3401 non-null   float64
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     3388 non-null   object
#  9   Status Code                       3401 non-null   object
#  10  Expected Date                     0 non-null      float64
#  11  Groups With Access Code           3401 non-null   object
#  12  Access Days Time                  2568 non-null   object
#  13  Cards Accepted                    514 non-null    object
#  14  BD Blends                         3 non-null      object
#  15  NG Fill Type Code                 10 non-null     object
#  16  NG PSI                            10 non-null     float64
#  17  EV Level1 EVSE Num                1 non-null      float64
#  18  EV Level2 EVSE Num                2893 non-null   float64
#  19  EV DC Fast Count                  172 non-null    float64
#  20  EV Other Info                     0 non-null      float64
#  21  EV Network                        3046 non-null   object
#  22  EV Network Web                    2817 non-null   object
#  23  Geocode Status                    3174 non-null   object
#  24  Latitude                          3174 non-null   float64
#  25  Longitude                         3174 non-null   float64
#  26  Date Last Confirmed               3169 non-null   object
#  27  ID                                3174 non-null   float64
#  28  Updated At                        3174 non-null   datetime64[ns]
#  29  Owner Type Code                   1130 non-null   object
#  30  Federal Agency ID                 0 non-null      float64
#  31  Federal Agency Name               0 non-null      float64
#  32  Open Date                         3172 non-null   object
#  33  Hydrogen Status Link              0 non-null      float64
#  34  NG Vehicle Class                  10 non-null     object
#  35  LPG Primary                       42 non-null     object
#  36  E85 Blender Pump                  73 non-null     object
#  37  EV Connector Types                3046 non-null   object
#  38  Country                           3174 non-null   object
#  39  Intersection Directions (French)  0 non-null      float64
#  40  Access Days Time (French)         0 non-null      float64
#  41  BD Blends (French)                0 non-null      float64
#  42  Groups With Access Code (French)  3174 non-null   object
#  43  Hydrogen is Retail                0 non-null      float64
#  44  Access Code                       3174 non-null   object
#  45  Access Detail Code                306 non-null    object
#  46  Federal Agency Code               0 non-null      float64
#  47  Facility Type                     1030 non-null   object
#  48  CNG Dispenser Num                 10 non-null     float64
#  49  CNG On-Site Renewable Source      7 non-null      object
#  50  CNG Total Compression Capacity    7 non-null      float64
#  51  CNG Storage Capacity              5 non-null      float64
#  52  LNG On-Site Renewable Source      0 non-null      float64
#  53  E85 Other Ethanol Blends          3 non-null      object
#  54  EV Pricing                        693 non-null    object
#  55  EV Pricing (French)               0 non-null      float64
#  56  LPG Nozzle Types                  40 non-null     object
#  57  Hydrogen Pressures                0 non-null      float64
#  58  Hydrogen Standards                0 non-null      float64
#  59  CNG Fill Type Code                10 non-null     object
#  60  CNG PSI                           10 non-null     float64
#  61  CNG Vehicle Class                 10 non-null     object
#  62  LNG Vehicle Class                 0 non-null      float64
#  63  EV On-Site Renewable Source       33 non-null     object
#  64  Georeference                      3171 non-null   object
# dtypes: datetime64[ns](1), float64(28), object(36)
# memory usage: 1.7+ MB

# %%
ny_stations.isna().mean()
# Out:
# Fuel Type Code                      0.000000
# Station Name                        0.000000
# Street Address                      0.000000
# Intersection Directions             0.965639
# City                                0.001175
# State                               0.001175
# ZIP                                 0.001175
# Plus4                               1.000000
# Station Phone                       0.004993
# Status Code                         0.001175
# Expected Date                       1.000000
# Groups With Access Code             0.001175
# Access Days Time                    0.245815
# Cards Accepted                      0.849046
# BD Blends                           0.999119
# NG Fill Type Code                   0.997063
# NG PSI                              0.997063
# EV Level1 EVSE Num                  0.999706
# EV Level2 EVSE Num                  0.150367
# EV DC Fast Count                    0.949486
# EV Other Info                       1.000000
# EV Network                          0.105433
# EV Network Web                      0.172687
# Geocode Status                      0.067841
# Latitude                            0.067841
# Longitude                           0.067841
# Date Last Confirmed                 0.069310
# ID                                  0.067841
# Updated At                          0.067841
# Owner Type Code                     0.668135
# Federal Agency ID                   1.000000
# Federal Agency Name                 1.000000
# Open Date                           0.068429
# Hydrogen Status Link                1.000000
# NG Vehicle Class                    0.997063
# LPG Primary                         0.987665
# E85 Blender Pump                    0.978561
# EV Connector Types                  0.105433
# Country                             0.067841
# Intersection Directions (French)    1.000000
# Access Days Time (French)           1.000000
# BD Blends (French)                  1.000000
# Groups With Access Code (French)    0.067841
# Hydrogen is Retail                  1.000000
# Access Code                         0.067841
# Access Detail Code                  0.910132
# Federal Agency Code                 1.000000
# Facility Type                       0.697504
# CNG Dispenser Num                   0.997063
# CNG On-Site Renewable Source        0.997944
# CNG Total Compression Capacity      0.997944
# CNG Storage Capacity                0.998532
# LNG On-Site Renewable Source        1.000000
# E85 Other Ethanol Blends            0.999119
# EV Pricing                          0.796476
# EV Pricing (French)                 1.000000
# LPG Nozzle Types                    0.988253
# Hydrogen Pressures                  1.000000
# Hydrogen Standards                  1.000000
# CNG Fill Type Code                  0.997063
# CNG PSI                             0.997063
# CNG Vehicle Class                   0.997063
# LNG Vehicle Class                   1.000000
# EV On-Site Renewable Source         0.990308
# Georeference                        0.068722
# dtype: float64

# %% [markdown]
# ### Verify the unique values per column

# %%
(ny_stations.dropna(axis=1, how='all')
            .nunique())
# Out:
# Fuel Type Code                         5
# Station Name                        3328
# Street Address                      2691
# Intersection Directions              111
# City                                 612
# State                                  1
# ZIP                                  732
# Station Phone                        777
# Status Code                            1
# Groups With Access Code                6
# Access Days Time                      79
# Cards Accepted                        40
# BD Blends                              2
# NG Fill Type Code                      1
# NG PSI                                 2
# EV Level1 EVSE Num                     1
# EV Level2 EVSE Num                    22
# EV DC Fast Count                       9
# EV Network                            18
# EV Network Web                        17
# Geocode Status                         3
# Latitude                            3132
# Longitude                           3131
# Date Last Confirmed                   26
# ID                                  3174
# Updated At                           110
# Owner Type Code                        5
# Open Date                           1001
# NG Vehicle Class                       2
# LPG Primary                            2
# E85 Blender Pump                       2
# EV Connector Types                    10
# Country                                1
# Groups With Access Code (French)       5
# Access Code                            1
# Access Detail Code                     4
# Facility Type                         42
# CNG Dispenser Num                      3
# CNG On-Site Renewable Source           1
# CNG Total Compression Capacity         7
# CNG Storage Capacity                   5
# E85 Other Ethanol Blends               2
# EV Pricing                            13
# LPG Nozzle Types                       3
# CNG Fill Type Code                     1
# CNG PSI                                2
# CNG Vehicle Class                      2
# EV On-Site Renewable Source            2
# Georeference                        3168
# dtype: int64

# %%
ny_stations_exp = (ny_stations
     .assign(
         Latitude = lambda dataset : dataset.Latitude.map(lambda lat: lat/(10**6)),
         Longitude = lambda dataset : dataset.Longitude.map(lambda lon: lon/(10**6))
   ))


fig = px.scatter_mapbox(ny_stations_exp,
                        lat='Latitude',
                        lon='Longitude',
                        zoom = 5,
                        hover_name = 'Station Name',
                        color_discrete_sequence = ['cyan'],
                        mapbox_style='carto-darkmatter')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="57cdb359-a180-494e-bd18-776729586f04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57cdb359-a180-494e-bd18-776729586f04")) {                    Plotly.newPlot(                        "57cdb359-a180-494e-bd18-776729586f04",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","hovertext":["Irish Propane","St. George Courthouse","Yonkers City Hall Parking Garage","Pawling","TOWN GERMANTOWN MUNICIPAL LOT","MINNEWASKA EV 1","TSS ALBANY STATIONS 1 & 2","1065 Elton St","Royal Development Manorville Square","266 13th St","COLE GROUP CEDAR PARK 2","123 Leonard St","Town of Minetto","PV Parking 40-07 73rd St - Tesla Destination","BEAVER LAKE BEAVER LAKE 2","Vision Nissan","ESF STATION 9","Flushing Plaza","Price Chopper - Tesla Supercharger","LIA HONDA SHOP1","ERIE COUNTY ELLIOTT CREEK","Popli Design Group","32 Burling Lane","STRONG MUSEUM STRONG L1 #2","WHITEFACE MT WHITEFACE 1","CPP CLUBHOUSE STATION 2","BA #1 7 AIRPORT PARK","ROSENBLUM300 GREAT OAKS 200","CITY OF GENEVA CITY HALL #1","S.A.N.Y. PARKING THREE","TEK AUTOMOTIVE CAP ALBANY 1","Modena Travel Plaza","Gideon Putnam Resort and Spa - Tesla Destination","Coveleigh Club","TONAWANDA YPR POOL PLAZA 1","854ELLICOTT 134 HIGH ST 3","Courtyard by Marriott Kingston - Tesla Destination","Glenwood Plaza","ADAMS STATION 401 ASTOR CT","Buffalo Niagara International Airport","Saint Regis Mohawk Health Services","MIDDLE COUNTRY PATRON PARKING","COMFORT INN COMFORT INN","NATIONAL GRID UNION COLLEGE","MB OF BUFFALO DC MERC BUFF 1","ShopRite","Hamilton College-Burke Library","Texas Roadhouse","Thacher State Park","MB OF BUFFALO EV MERC BUFF 2","Sunoco","EVolve NY Niagara Falls","Regeneron Troy","SCCC AMMERMAN 5","TPWC  TPWC 11A","FAYETTVL LIBRAY ORCHARD 2","The Spur - Tesla Destination","799 SENECA STATION 4","ATRIUM EVCHARGE PARKPLAZA EV1","30-10 35th Street","AECSOLAR STATION 3 AEC","854ELLICOTT 134 HIGH ST 5","Sylvan Parking - Pinnacle Garage","2112-2124 NY 7 EV3","WATERVLIET PARK 3","Parkright 39 E 29th Street - Tesla Destination","TATABROOKFIELD #7","CENTROTHERM CENTRO F1","Hampton Inn Garden City - Tesla Destination","APDC ADMIN LOT PORT 1.1","TOYOTA ELMIRA CT4020-1","Fairfield Inn & Suites by Marriott Canton","CAYUGA STATION ALL PRO GARAGE","Shops at Skyview center","iPark NYC 455 Central Park West - Tesla Destination","Comfort Inn-Corning - Tesla Destination","Saratoga Auto Museum - Tesla Destination","ERIE COUNTY ELMA MEADOWS","North 12 Parking (at the William Vale) - Tesla Supercharger","MONTANTE SOLAR STATION 5","iPark - Paradise Garage","286WAE 39 SHERIDAN AVE","NEW HARTFORD GW-1 1.2","SAVARINO COMPAN 500 SENECA 4","Tunnel Garage","Greymoor Way - Building 13A","City Parking RL Mercer Street - Tesla Destination","SRYMCASSB BATTENKILL 1.1","BORO PARK BORO CHARGE 7","Audi New Rochelle","Bridge Towers Location 1","Amada Tool America, INC","500 Packetts Landing","Starbuck Island North","iPark NYC 250 West Parking - Tesla Destination","Airport Executive Park","Cherry Street Parking Ramp","CANDLE CANDLEWOOD #1","ProPark 110-45 Queens Blvd - Tesla Destination","Clean Energy - Greenpoint - National Grid","NATIONAL GRID LONGWAYS DINER","MONTY'S EVSE EVSE4","LPCL STATION1","Loews Regency New York - Tesla Destination","BURNS MGT OXFORD 3","STONY BROOK UNV LIFE SCIENCES","Laureate Garage","CPLEV CPL","Kingston Nissan","SHELDON SUFFERN ORANGE AV APT 1","GHMC PARKINGGARAGE6","SUNY NEW PALTZ STATION 3","BURNS MGT SGA 5","LIVONIA CSD CONNELL 3","PANYNJ LGA WEST 4","Icon Parking 30 W 63rd St - Tesla Destination","Peppermints Restaurant - Tesla Destination","FAIRGROUND VILL STATION 1","MATTHEW IMPORT STATION 1","SRYMCASSB WILTON 1.4","GLOVE ...

# %% [markdown]
# ## Cleaning the dataset

# %%
def fix_date_format(date):
    result = re.search(r'(\d\d)/(\d\d)/(\d\d\d\d)', str(date))
    if result != None:
      (month, day, year) = result.groups()
      date = f'{year}-{month}-{day}'
    return date

missing_values = {'EV_Network':'Not electric', 'EV_Connector_Types': 'Not electric'}

ny_stations = (ny_stations  
    .filter(['Fuel Type Code', 'Station Name', 'Street Adress','City',
             'ZIP','Station Code','EV Network','Latitude',
             'Longitude','Date Last Confirmed','Open Date',
             'EV Connector Types'])
    .rename(columns=lambda name: re.sub(' ','_',name))   
    .fillna(missing_values)
    .dropna()
    .assign(
           Date_Last_Confirmed = lambda dataset : dataset.Date_Last_Confirmed.map(fix_date_format),
           Open_Date = lambda dataset : dataset.Open_Date.map(fix_date_format)
    )
    .assign(
         Date_Last_Confirmed = lambda dataset : pd.to_datetime(dataset.Date_Last_Confirmed, format='%Y-%m-%d'),
         Open_Date = lambda dataset : pd.to_datetime(dataset.Open_Date, format='%Y-%m-%d'),
         Latitude = lambda dataset : dataset.Latitude.map(lambda lat: lat/(10**6)),
         Longitude = lambda dataset : dataset.Longitude.map(lambda lon: lon/(10**6)),
        ZIP = lambda dataset : dataset.ZIP.astype('int')
   )
   .query('Longitude > -80 and Longitude < -70')
)
# Out:
# <ipython-input-20-0baa8032c3d1>:19: FutureWarning:
#
# Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#
# <ipython-input-20-0baa8032c3d1>:20: FutureWarning:
#
# Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])

# %%
ny_stations.isna().mean()
# Out:
# Fuel_Type_Code         0.0
# Station_Name           0.0
# City                   0.0
# ZIP                    0.0
# EV_Network             0.0
# Latitude               0.0
# Longitude              0.0
# Date_Last_Confirmed    0.0
# Open_Date              0.0
# EV_Connector_Types     0.0
# dtype: float64

# %% [markdown]
# ## Visualización

# %%
fig = px.scatter_mapbox(ny_stations,
                        lat='Latitude',
                        lon='Longitude',
                        zoom = 5,
                        hover_name = 'Station_Name',
                        hover_data = ['Fuel_Type_Code', 'EV_Connector_Types'],
                        color = 'Fuel_Type_Code',
                        mapbox_style='carto-darkmatter')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8ae0e970-a7dc-42e2-ae9e-d4a47d2a61f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ae0e970-a7dc-42e2-ae9e-d4a47d2a61f3")) {                    Plotly.newPlot(                        "8ae0e970-a7dc-42e2-ae9e-d4a47d2a61f3",                        [{"customdata":[["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"]],"hovertemplate":"<b>%{hovertext}</b><br><br>Fuel_Type_Code=%{customdata[0]}<br>Latitude=%{lat}<br>Longitude=%{lon}<br>EV_Connector_Types=%{customdata[1]}<extra></extra>","hovertext":["Irish Propane","U-Haul","U-Haul","Ideal Bottle Gas","U-Haul","U-Haul","Kelly's Convenience Corner","Starlite Propane Gas Corp","U-Haul","U-Haul","All Gas & Welding Supply Co","U-Haul","U-Haul","U-Haul","U-Haul","Island Park Propane","U-Haul","Port Henry Service Center","U-Haul","U-Haul","U-Haul","U-Haul","U-Haul","U-Haul","U-Haul","Combined Energy Services","U-Haul","U-Haul","U-Haul","U-Haul","U-Haul","U-Haul","All Gas & Welding Supply Co","Combined Energy Services","U-Haul","Mirabito Fuels","Lictus Keystone","Gladstone Sunoco","U-Haul","U-Haul","U-Haul","Combined Energy Services"],"lat":[42.860108,42.095627,42.923615,40.806551,42.923473,40.743589,42.837537,40.763364,43.125565,43.943911,41.641505,43.084039,43.104675,42.749852,40.851029,40.613916,40.780796,44.033647,42.800131,43.297135,43.201343,42.15063,40.658112,42.423865,42.641484,41.771445,43.051679,43.204326,41.663631,43.186095,44.610911,43.032604,41.088596,41.651953,42.979843,42.103146,42.020413,43.0443,42.774228,43.092951,41.466227,41.397445],"legendgroup":"LPG","lon":[-78.859226,-75.981663,-76.581206,-72.947099,-78.696704,-73.498311,-74.869904,-73.29003,-76.107338,-75.91733,-74.640756,-75.289786,-78.980875,-73.867904,-73.160001,-73.646191,-73.558148,-73.462166,-78.752089,-73.675593,-77.567113,-76.833014,-73.634055,-76.513925,-73.750972,-74.313151,-76.124668,-75.456128,-73.928773,-77.702153,-75.123441,-77.444356,-73.949068,-74.672938,-78.911044,-75.998508,-79.634017,-77.659377,-73.693527,-77.652374,-74.050373,-74.384605],"marker":{"color":"#636efa"},"mode":"markers","name":"LPG","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","CHADEMO J1772COMBO"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","TESLA"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","CHADEMO J1772COMBO"],["ELEC","J1772 TESLA"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772 TESLA"],["ELEC","J1772"],["ELEC","J1772"],["ELEC","J1772"], ...

# %%
fig = px.scatter_mapbox(ny_stations,
                        lat='Latitude',
                        lon='Longitude',
                        zoom = 5,
                        hover_name = 'Station_Name',
                        hover_data = ['Fuel_Type_Code', 'EV_Network',],
                        color = 'EV_Network',
                        mapbox_style='carto-darkmatter')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="686075e0-2d17-4236-b5de-a8f780271716" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("686075e0-2d17-4236-b5de-a8f780271716")) {                    Plotly.newPlot(                        "686075e0-2d17-4236-b5de-a8f780271716",                        [{"customdata":[["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["BD","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["BD","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["CNG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["CNG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["CNG","Not electric"],["E85","Not electric"],["E85","Not electric"],["CNG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["CNG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["CNG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["BD","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["CNG","Not electric"],["LPG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["CNG","Not electric"],["E85","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["CNG","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["E85","Not electric"],["E85","Not electric"],["LPG","Not electric"],["CNG","Not electric"],["LPG","Not electric"],["LPG","Not electric"],["LPG","Not electric"]],"hovertemplate":"<b>%{hovertext}</b><br><br>EV_Network=%{customdata[1]}<br>Latitude=%{lat}<br>Longitude=%{lon}<br>Fuel_Type_Code=%{customdata[0]}<extra></extra>","hovertext":["Irish Propane","ShopRite","Sunoco","U-Haul","OK Petroleum","JOE'S KWIK MARTS #0471","Conoco","Valero","U-Haul","BP","Citgo","Shell - Water Mill Fuel Complex","John Ray & Sons","Valero","Ideal Bottle Gas","Citgo","BP","Valero - Mount Sinai","Mirabito Travel Center","Gasoline Heaven - Gulf","Valero - Hospital Road","U-Ha ...
